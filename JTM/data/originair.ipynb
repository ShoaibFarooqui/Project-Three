# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd
from datetime import datetime
import turfpy as tp

# %%
mongo = MongoClient(port=27017)

# %%
# !mongoimport --type csv -d ORIGINATION  -c LATLONG --headerline --drop "JESSICAAAAA.csv"
# Out:
# 2023-04-20T17:10:10.193-0500	connected to: mongodb://localhost/
# 2023-04-20T17:10:10.195-0500	dropping: ORIGINATION.LATLONG
# 2023-04-20T17:10:10.263-0500	49 document(s) imported successfully. 0 document(s) failed to import.

# %%
db = mongo.ORIGINATION # database
latlong= db.LATLONG # collection

# %%
print(db.list_collection_names())
# Out:
# ['LATLONG']

# %%
db = pd.DataFrame(list(latlong.find()))

# %%
db
# Out:
#                          _id flight no              origin origin airport
# 0   6441b842aa9d854667f55fcc    WEW282    59.334, -107.181            ZFD
# 1   6441b842aa9d854667f55fcd     OJ256      6.498, -58.253            GEO
# 2   6441b842aa9d854667f55fce    H63190    59.755, -161.845            KWN
# 3   6441b842aa9d854667f55fcf     A1310      -7.926,112.714            MLG
# 4   6441b842aa9d854667f55fd0      C271       14.739,-17.49            DKR
# 5   6441b842aa9d854667f55fd1    5C9916       9.85, -85.366            PBP
# 6   6441b842aa9d854667f55fd2    PC2193       38.292,27.157            ADB
# 7   6441b842aa9d854667f55fd3     FZ981       25.255,55.364            DXB
# 8   6441b842aa9d854667f55fd4      PX73       6.985,158.209            PNI
# 9   6441b842aa9d854667f55fd5     SJ182      -6.126,106.656            CGK
# 10  6441b842aa9d854667f55fd6     YT691       27.696,85.359            KTM
# 11  6441b842aa9d854667f55fd7    EP3704       35.689,51.313            THR
# ...
